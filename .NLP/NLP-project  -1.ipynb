# %%
# !pip install nltk
# !pip install wordcloud

# %%
# you can also create your own words
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of
humans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and
problem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.
It is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe
AI could solve major challenges and crisis situations.'''
type(AI)

# sentence tokenize AI and check length
from nltk.tokenize import sent_tokenize
AI_sent = sent_tokenize(AI)
AI_sent
len(AI_sent)

# Word tokenise AI and check length
from nltk.tokenize import word_tokenize
AI_word = word_tokenize(AI)
AI_word
len(AI_word)

# we tokenize a paragraph and check length
from nltk.tokenize import blankline_tokenize
AI_blank = blankline_tokenize(AI)
AI_blank
len(AI_blank)

#"WhitespaceTokenizer is a tokenizer in NLTK that splits the text based only on spaces, tabs, and newlines"
from nltk.tokenize import  WhitespaceTokenizer
wt =  WhitespaceTokenizer().tokenize(AI)
wt
print(len(wt))

s = "good apple cost $3.66 in hydrabad please buy"
s

#It splits text into words and punctuations.separatly
from nltk.tokenize import wordpunct_tokenize
wpt = wordpunct_tokenize(s)
wpt
len(wpt)

#
from nltk.util import bigrams,trigrams,ngrams
import nltk
nltk.download('punkt')
string  = 'we are student of kodi prakash senapati from 5:30 betch'
quotes_tokens = nltk.word_tokenize(string)
quotes_tokens

quotes_bigrams = list(bigrams(quotes_tokens))
quotes_bigrams
len(quotes_bigrams)


quotes_trigrams = list(nltk.trigrams(quotes_tokens))
quotes_trigrams
len(quotes_trigrams)

quotes_ngrams = list(nltk.ngrams(quotes_tokens,4))
quotes_ngrams
len(quotes_tokens)


from nltk.stem import PorterStemmer
pst = PorterStemmer()

pst.stem('affection')

pst.stem('playing')

pst.stem('maximum')

pst.stem('singing')

pst.stem('dancing')

words_to_stem=['give','giving','given', 'gave']
for words in words_to_stem:
    print(words+ ' : ' +pst.stem(words))

words_to_stem=['give','giving','given', 'gave','thinking', 'loving', 'maximum']
for words in words_to_stem:
    print(words+ ' : ' +pst.stem(words))
    
    
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
lst
from nltk.stem import SnowballStemmer
sbs = SnowballStemmer('english')
sbs
# Out:
# 70
# give : give
# giving : give
# given : given
# gave : gave
# give : give
# giving : give
# given : given
# gave : gave
# thinking : think
# loving : love
# maximum : maximum
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import  wordnet
from nltk.stem import WordNetLemmatizer
words_lem = WordNetLemmatizer()

words_to_stem

for word in words_to_stem:
    print(words+ ' : ' +words_lem.lemmatize(words)) 
    
    # don't allow national language
from nltk.corpus import stopwords
stopwords.words('english')

len(stopwords.words('english'))


stopwords.words('chinese')
len(stopwords.words('chinese'))

stopwords.words('french')
len(stopwords.words('french'))

stopwords.words('german')
len(stopwords.words('german'))

from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
sent = 'sam is natural wen it comes to drawing'
sent_tokens = word_tokenize(sent)
sent_tokens

for token in sent_tokens:
    print(nltk.pos_tag([token]))
    

sent2 = 'john is eating adelicious cake'
sent2_tokens = word_tokenize(sent2)
sent2_tokens   

for token in sent2_tokens:
    print(nltk.pos_tag([token]))


from wordcloud import WordCloud
import matplotlib.pyplot as plt

company_names = [
    "Google", "Microsoft", "Apple", "Amazon", "Facebook", "Tesla", "IBM", "Intel", "Samsung", "Oracle",
    "Adobe", "Salesforce", "Cisco", "Nvidia", "Qualcomm", "Accenture", "Capgemini", "TCS", "Infosys", "Wipro",
    "HCL", "Tech Mahindra", "LTI", "Mindtree", "Cognizant", "Deloitte", "EY", "PwC", "KPMG", "ZS Associates",
    "JP Morgan", "Goldman Sachs", "Morgan Stanley", "Barclays", "HSBC", "American Express", "Visa", "Mastercard",
    "PayPal", "Razorpay", "PhonePe", "Google Pay", "Kotak", "HDFC Bank", "ICICI Bank", "Axis Bank", "SBI", "Yes Bank",
    "Bajaj Finserv", "Bajaj Finance", "Mahindra", "Tata", "Tata Motors", "Tata Steel", "Tata Power", "Maruti", "Hyundai", "Kia",
    "Ford", "Honda", "Ola", "Uber", "Swiggy", "Zomato", "Blinkit", "BigBasket", "Jio", "Airtel", "Vi",
    "Reliance", "Adani", "Nestle", "PepsiCo", "Coca-Cola", "ITC", "HUL", "P&G", "Colgate", "Britannia",
    "Parle", "Amul", "L&T", "Siemens", "ABB", "Bosch", "Philips", "Hitachi", "Panasonic", "LG",
    "Dell", "HP", "Lenovo", "Asus", "Acer", "Flipkart", "Meesho", "Myntra", "Snapdeal", "Nykaa",
    "BYJU'S", "Unacademy", "Vedantu", "PhysicsWallah", "WhiteHat Jr", "Zerodha", "Groww", "Upstox", "Angel One", "CoinDCX",
    "WazirX", "Freshworks", "Zoho", "Rivigo", "CureFit", "Urban Company", "Dream11", "Nazara", "Gameskraft", "PhonePe",
    "Turing", "Andela", "Fiverr", "Upwork", "Toptal", "WeWork", "LinkedIn", "Spotify", "Netflix", "Hotstar",
    "Sony", "Disney", "Redbus", "MakeMyTrip", "Yatra", "EaseMyTrip", "Ixigo", "Boat", "Noise", "Realme",
    "OnePlus", "Xiaomi", "Vivo", "Oppo", "Infinix", "Tecno", "Micromax", "Karbonn", "Lava", "Nothing"
]

# Generate a word cloud from the company names
wc = WordCloud(width=700, height=500, background_color='black').generate(' '.join(company_names))

# Display the word cloud
plt.figure(figsize=(7, 4))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')  # Hide the axes    
plt.title('Word Cloud of Company Names', fontsize=20, color='white')
plt.show()
# Out:
# maximum : maximum
# maximum : maximum
# maximum : maximum
# maximum : maximum
# maximum : maximum
# maximum : maximum
# maximum : maximum
# [('sam', 'NN')]
# [('is', 'VBZ')]
# [('natural', 'JJ')]
# [('wen', 'NN')]
# [('it', 'PRP')]
# [('comes', 'VBZ')]
# [('to', 'TO')]
# [('drawing', 'VBG')]
# [('john', 'NN')]
# [('is', 'VBZ')]
# [('eating', 'VBG')]
# [('adelicious', 'JJ')]
# [('cake', 'NN')]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
